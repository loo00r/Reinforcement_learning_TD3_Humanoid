# %%
import gymnasium as gym
from stable_baselines3 import TD3, DDPG
from stable_baselines3.common.noise import NormalActionNoise
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback

# Клас для збору даних про винагороди
class RewardCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.rewards = []
        self.timesteps = []
        
    def _on_step(self):
        if len(self.model.ep_info_buffer) > 0:
            self.rewards.append(self.model.ep_info_buffer[-1]["r"])
            self.timesteps.append(self.model.num_timesteps)
        return True

# Створюємо середовище
env = gym.make("Humanoid-v5")

# Визначаємо гіперпараметри TD3
n_actions = env.action_space.shape[0]

# Налаштування шуму для дослідження
action_noise = NormalActionNoise(
    mean=np.zeros(n_actions),
    sigma=0.1 * np.ones(n_actions)
)

# Створюємо TD3 модель
td3_model = TD3(
    "MlpPolicy",
    env,
    learning_rate=0.0003,          # Швидкість навчання актора
    learning_starts=10000,
    device='cuda',
    gradient_steps=1,
    batch_size=256,              # Розмір пакету
    action_noise=action_noise,    # Сигма (шум)
)

# Створюємо DDPG модель для порівняння
ddpg_model = DDPG(
    "MlpPolicy",
    env,
    learning_rate=0.0003,          # Швидкість навчання актора
    learning_starts=10000,
    device='cuda',
    gradient_steps=1,
    batch_size=256,              # Розмір пакету
    action_noise=action_noise, 
)

# Callbacks для збору даних
td3_callback = RewardCallback()
ddpg_callback = RewardCallback()

# Навчання моделей
print("Навчання TD3...")
td3_model.learn(total_timesteps=200000, callback=td3_callback)
print("Навчання DDPG...")
ddpg_model.learn(total_timesteps=200000, callback=ddpg_callback)

# Збереження моделей
td3_model.save("td3_humanoid")
ddpg_model.save("ddpg_humanoid")

# Візуалізація результатів
plt.figure(figsize=(10, 6))
plt.plot(td3_callback.timesteps, td3_callback.rewards, label='TD3')
plt.plot(ddpg_callback.timesteps, ddpg_callback.rewards, label='DDPG')
plt.xlabel('Часові кроки')
plt.ylabel('Повна винагорода')
plt.title('Порівняння TD3 і DDPG')
plt.legend()
plt.grid(True)
plt.savefig('comparison_plot.png')
plt.show()

# Тестування навченої моделі
env = gym.make("Humanoid-v4", render_mode="human")
obs, _ = env.reset()

for _ in range(1000):
    action, _ = td3_model.predict(obs, deterministic=True)
    obs, _, done, truncated, _ = env.step(action)
    if done or truncated:
        obs, _ = env.reset()

env.close()
# Out:
# c:\Users\g00n3\anaconda3\Lib\site-packages\gymnasium\envs\registration.py:517: DeprecationWarning: WARN: The environment Humanoid-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Навчання TD3...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | 122      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1103     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 96       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 145      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 178      |
# | train/             |          |
# |    actor_loss      | -5.45    |
# |    critic_loss     | 2.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 129      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 258      |
# | train/             |          |
# |    actor_loss      | -6.44    |
# |    critic_loss     | 0.884    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 157      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 124      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 341      |
# | train/             |          |
# |    actor_loss      | -7.37    |
# |    critic_loss     | 0.405    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 240      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 120      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 424      |
# | train/             |          |
# |    actor_loss      | -8.01    |
# |    critic_loss     | 0.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 323      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 118      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 506      |
# | train/             |          |
# |    actor_loss      | -8.77    |
# |    critic_loss     | 0.313    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 405      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 116      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 590      |
# | train/             |          |
# |    actor_loss      | -9.61    |
# |    critic_loss     | 0.591    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 489      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 115      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 674      |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 0.678    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 573      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 114      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 791      |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 1.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 690      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 113      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 926      |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 1.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 825      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.6     |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 113      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1038     |
# | train/             |          |
# |    actor_loss      | -14.3    |
# |    critic_loss     | 2.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 937      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | 119      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 112      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1146     |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.816    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1045     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | 120      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 112      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1253     |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 6.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1152     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.3     |
# |    ep_rew_mean     | 121      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 111      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1362     |
# | train/             |          |
# |    actor_loss      | -17.2    |
# |    critic_loss     | 1.82     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1261     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | 122      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 111      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1472     |
# | train/             |          |
# |    actor_loss      | -19.2    |
# |    critic_loss     | 1.87     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1371     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 111      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1589     |
# | train/             |          |
# |    actor_loss      | -19      |
# |    critic_loss     | 2.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1488     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 111      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1701     |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 2        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.2     |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 110      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1816     |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 3.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1715     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.4     |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 108      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1928     |
# | train/             |          |
# |    actor_loss      | -22.2    |
# |    critic_loss     | 4.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1827     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.6     |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 107      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2052     |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 1.33     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1951     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 106      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2174     |
# | train/             |          |
# |    actor_loss      | -24.8    |
# |    critic_loss     | 3.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2073     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26       |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 106      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2290     |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 2.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2189     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.9     |
# |    ep_rew_mean     | 135      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 105      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2475     |
# | train/             |          |
# |    actor_loss      | -28.8    |
# |    critic_loss     | 6.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2374     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 104      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2533     |
# | train/             |          |
# |    actor_loss      | -27.4    |
# |    critic_loss     | 5.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2432     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 103      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2738     |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2637     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.3     |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 103      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2925     |
# | train/             |          |
# |    actor_loss      | -29.7    |
# |    critic_loss     | 6.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2824     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.1     |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 102      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 3093     |
# | train/             |          |
# |    actor_loss      | -34      |
# |    critic_loss     | 4.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2992     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.8     |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 102      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 3242     |
# | train/             |          |
# |    actor_loss      | -35.2    |
# |    critic_loss     | 4.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3141     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.4     |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 101      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 3382     |
# | train/             |          |
# |    actor_loss      | -34.7    |
# |    critic_loss     | 3.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3281     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31       |
# |    ep_rew_mean     | 155      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 101      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 3521     |
# | train/             |          |
# |    actor_loss      | -36.5    |
# |    critic_loss     | 5.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3420     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.4     |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 100      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 3644     |
# | train/             |          |
# |    actor_loss      | -36.4    |
# |    critic_loss     | 7.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3543     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.6     |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 100      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 3747     |
# | train/             |          |
# |    actor_loss      | -36.2    |
# |    critic_loss     | 4.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3646     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.6     |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 100      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 3839     |
# | train/             |          |
# |    actor_loss      | -38.7    |
# |    critic_loss     | 9.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3738     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.4     |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 101      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 3931     |
# | train/             |          |
# |    actor_loss      | -37.7    |
# |    critic_loss     | 7.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3830     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.9     |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 101      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 4018     |
# | train/             |          |
# |    actor_loss      | -38.3    |
# |    critic_loss     | 4.95     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3917     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.7     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 101      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 4106     |
# | train/             |          |
# |    actor_loss      | -40.6    |
# |    critic_loss     | 5.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4005     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.5     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 101      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 4196     |
# | train/             |          |
# |    actor_loss      | -39.8    |
# |    critic_loss     | 3.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4095     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.4     |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 101      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 4288     |
# | train/             |          |
# |    actor_loss      | -41.8    |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4187     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.2     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 101      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 4381     |
# | train/             |          |
# |    actor_loss      | -40.6    |
# |    critic_loss     | 7.08     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4280     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 101      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 4472     |
# | train/             |          |
# |    actor_loss      | -40.7    |
# |    critic_loss     | 6.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4371     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.8     |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 102      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 4567     |
# | train/             |          |
# |    actor_loss      | -41.7    |
# |    critic_loss     | 6.22     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4466     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 102      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 4661     |
# | train/             |          |
# |    actor_loss      | -41.2    |
# |    critic_loss     | 9.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4560     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.4     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 102      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 4758     |
# | train/             |          |
# |    actor_loss      | -44.2    |
# |    critic_loss     | 7.08     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4657     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.3     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 102      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 4854     |
# | train/             |          |
# |    actor_loss      | -40.2    |
# |    critic_loss     | 7.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4753     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29       |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 102      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 4953     |
# | train/             |          |
# |    actor_loss      | -45.6    |
# |    critic_loss     | 6.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4852     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.8     |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 102      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 5054     |
# | train/             |          |
# |    actor_loss      | -43.9    |
# |    critic_loss     | 7.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4953     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.6     |
# |    ep_rew_mean     | 144      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 102      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 5153     |
# | train/             |          |
# |    actor_loss      | -44.4    |
# |    critic_loss     | 10.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5052     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.8     |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 102      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 5258     |
# | train/             |          |
# |    actor_loss      | -47.9    |
# |    critic_loss     | 10.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5157     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.3     |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 102      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 5362     |
# | train/             |          |
# |    actor_loss      | -48.5    |
# |    critic_loss     | 5.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5261     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 102      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 5468     |
# | train/             |          |
# |    actor_loss      | -45.7    |
# |    critic_loss     | 4.51     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5367     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.5     |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 102      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 5577     |
# | train/             |          |
# |    actor_loss      | -46.1    |
# |    critic_loss     | 7.14     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5476     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 102      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 5684     |
# | train/             |          |
# |    actor_loss      | -49.9    |
# |    critic_loss     | 13.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5583     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 103      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 5791     |
# | train/             |          |
# |    actor_loss      | -48.6    |
# |    critic_loss     | 8.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5690     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 103      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 5897     |
# | train/             |          |
# |    actor_loss      | -47.2    |
# |    critic_loss     | 5.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5796     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 103      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 6003     |
# | train/             |          |
# |    actor_loss      | -48      |
# |    critic_loss     | 4.04     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5902     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.6     |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 103      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 6106     |
# | train/             |          |
# |    actor_loss      | -50      |
# |    critic_loss     | 5.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6005     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 103      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 6201     |
# | train/             |          |
# |    actor_loss      | -49.1    |
# |    critic_loss     | 5.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6100     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.5     |
# |    ep_rew_mean     | 123      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 103      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 6289     |
# | train/             |          |
# |    actor_loss      | -50.6    |
# |    critic_loss     | 7.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6188     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.7     |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 103      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 6397     |
# | train/             |          |
# |    actor_loss      | -52.6    |
# |    critic_loss     | 10.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6296     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 103      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 6505     |
# | train/             |          |
# |    actor_loss      | -51.8    |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6404     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 103      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 6612     |
# | train/             |          |
# |    actor_loss      | -53.4    |
# |    critic_loss     | 4.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6511     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.2     |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 103      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 6719     |
# | train/             |          |
# |    actor_loss      | -53.4    |
# |    critic_loss     | 10.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6618     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.4     |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 103      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 6824     |
# | train/             |          |
# |    actor_loss      | -52.8    |
# |    critic_loss     | 6.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6723     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 103      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 6931     |
# | train/             |          |
# |    actor_loss      | -52.5    |
# |    critic_loss     | 7.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6830     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.8     |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 103      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 7051     |
# | train/             |          |
# |    actor_loss      | -51.6    |
# |    critic_loss     | 6.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6950     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.1     |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 103      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 7181     |
# | train/             |          |
# |    actor_loss      | -52.5    |
# |    critic_loss     | 6.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7080     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 103      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 7303     |
# | train/             |          |
# |    actor_loss      | -52.4    |
# |    critic_loss     | 7.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7202     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.7     |
# |    ep_rew_mean     | 134      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 103      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 7428     |
# | train/             |          |
# |    actor_loss      | -54.4    |
# |    critic_loss     | 6.86     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7327     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | 136      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 103      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 7567     |
# | train/             |          |
# |    actor_loss      | -56.5    |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7466     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.5     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 103      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 7705     |
# | train/             |          |
# |    actor_loss      | -55.5    |
# |    critic_loss     | 5.75     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7604     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.9     |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 104      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 7848     |
# | train/             |          |
# |    actor_loss      | -57.2    |
# |    critic_loss     | 39.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7747     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.5     |
# |    ep_rew_mean     | 144      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 104      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 8001     |
# | train/             |          |
# |    actor_loss      | -53      |
# |    critic_loss     | 9.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7900     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.9     |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 104      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 8151     |
# | train/             |          |
# |    actor_loss      | -55.4    |
# |    critic_loss     | 8.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8050     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 104      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 8281     |
# | train/             |          |
# |    actor_loss      | -58.1    |
# |    critic_loss     | 9.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8180     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.5     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 104      |
# |    time_elapsed    | 80       |
# |    total_timesteps | 8416     |
# | train/             |          |
# |    actor_loss      | -61.2    |
# |    critic_loss     | 7.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8315     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.7     |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 104      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 8546     |
# | train/             |          |
# |    actor_loss      | -54.4    |
# |    critic_loss     | 11       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8445     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.9     |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 103      |
# |    time_elapsed    | 83       |
# |    total_timesteps | 8679     |
# | train/             |          |
# |    actor_loss      | -59.2    |
# |    critic_loss     | 7.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8578     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.3     |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 103      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 8820     |
# | train/             |          |
# |    actor_loss      | -62.6    |
# |    critic_loss     | 6.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8719     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.6     |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 103      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 8961     |
# | train/             |          |
# |    actor_loss      | -52.6    |
# |    critic_loss     | 10.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8860     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.9     |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 102      |
# |    time_elapsed    | 88       |
# |    total_timesteps | 9095     |
# | train/             |          |
# |    actor_loss      | -64.4    |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8994     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.3     |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 102      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 9234     |
# | train/             |          |
# |    actor_loss      | -59.5    |
# |    critic_loss     | 6.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9133     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.7     |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 102      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 9373     |
# | train/             |          |
# |    actor_loss      | -60.5    |
# |    critic_loss     | 5.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9272     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.2     |
# |    ep_rew_mean     | 166      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 101      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 9514     |
# | train/             |          |
# |    actor_loss      | -63.6    |
# |    critic_loss     | 5.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9413     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.5     |
# |    ep_rew_mean     | 167      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 101      |
# |    time_elapsed    | 95       |
# |    total_timesteps | 9648     |
# | train/             |          |
# |    actor_loss      | -61.7    |
# |    critic_loss     | 9.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9547     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.8     |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 100      |
# |    time_elapsed    | 96       |
# |    total_timesteps | 9785     |
# | train/             |          |
# |    actor_loss      | -62.9    |
# |    critic_loss     | 10       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9684     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.9     |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 100      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 9906     |
# | train/             |          |
# |    actor_loss      | -62.4    |
# |    critic_loss     | 6.88     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9805     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33       |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 100      |
# |    time_elapsed    | 99       |
# |    total_timesteps | 10020    |
# | train/             |          |
# |    actor_loss      | -57.7    |
# |    critic_loss     | 10.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9919     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.1     |
# |    ep_rew_mean     | 171      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 100      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 10135    |
# | train/             |          |
# |    actor_loss      | -55.3    |
# |    critic_loss     | 10.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10034    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.2     |
# |    ep_rew_mean     | 171      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 100      |
# |    time_elapsed    | 102      |
# |    total_timesteps | 10249    |
# | train/             |          |
# |    actor_loss      | -60.3    |
# |    critic_loss     | 11.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10148    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.1     |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 99       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 10362    |
# | train/             |          |
# |    actor_loss      | -61      |
# |    critic_loss     | 11.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10261    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33       |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 99       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 10478    |
# | train/             |          |
# |    actor_loss      | -61.6    |
# |    critic_loss     | 18.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10377    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.9     |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 99       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 10592    |
# | train/             |          |
# |    actor_loss      | -63.9    |
# |    critic_loss     | 8.31     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10491    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.8     |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 99       |
# |    time_elapsed    | 107      |
# |    total_timesteps | 10706    |
# | train/             |          |
# |    actor_loss      | -63.2    |
# |    critic_loss     | 7.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10605    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.5     |
# |    ep_rew_mean     | 166      |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 99       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 10820    |
# ...
# |    critic_loss     | 2.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35188    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 1076     |
# |    fps             | 99       |
# |    time_elapsed    | 355      |
# |    total_timesteps | 35437    |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 5.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35336    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 1080     |
# |    fps             | 99       |
# |    time_elapsed    | 357      |
# |    total_timesteps | 35580    |
# | train/             |          |
# |    actor_loss      | -73.5    |
# |    critic_loss     | 4.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35479    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 1084     |
# |    fps             | 99       |
# |    time_elapsed    | 358      |
# |    total_timesteps | 35721    |
# | train/             |          |
# |    actor_loss      | -84.7    |
# |    critic_loss     | 5.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35620    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 1088     |
# |    fps             | 99       |
# |    time_elapsed    | 359      |
# |    total_timesteps | 35861    |
# | train/             |          |
# |    actor_loss      | -81      |
# |    critic_loss     | 3.08     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35760    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36       |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 1092     |
# |    fps             | 99       |
# |    time_elapsed    | 361      |
# |    total_timesteps | 36005    |
# | train/             |          |
# |    actor_loss      | -86.5    |
# |    critic_loss     | 3.22     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35904    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.9     |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 1096     |
# |    fps             | 99       |
# |    time_elapsed    | 362      |
# |    total_timesteps | 36149    |
# | train/             |          |
# |    actor_loss      | -83.3    |
# |    critic_loss     | 2.85     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36048    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.8     |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 99       |
# |    time_elapsed    | 363      |
# |    total_timesteps | 36288    |
# | train/             |          |
# |    actor_loss      | -78.4    |
# |    critic_loss     | 2.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36187    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.8     |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 1104     |
# |    fps             | 99       |
# |    time_elapsed    | 365      |
# |    total_timesteps | 36431    |
# | train/             |          |
# |    actor_loss      | -75.9    |
# |    critic_loss     | 6.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36330    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 1108     |
# |    fps             | 99       |
# |    time_elapsed    | 366      |
# |    total_timesteps | 36571    |
# | train/             |          |
# |    actor_loss      | -79.1    |
# |    critic_loss     | 3.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36470    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 1112     |
# |    fps             | 99       |
# |    time_elapsed    | 367      |
# |    total_timesteps | 36720    |
# | train/             |          |
# |    actor_loss      | -85.3    |
# |    critic_loss     | 4.75     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36619    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 1116     |
# |    fps             | 99       |
# |    time_elapsed    | 369      |
# |    total_timesteps | 36863    |
# | train/             |          |
# |    actor_loss      | -81      |
# |    critic_loss     | 4.63     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36762    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1120     |
# |    fps             | 99       |
# |    time_elapsed    | 370      |
# |    total_timesteps | 37005    |
# | train/             |          |
# |    actor_loss      | -78.6    |
# |    critic_loss     | 4.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36904    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.6     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1124     |
# |    fps             | 99       |
# |    time_elapsed    | 371      |
# |    total_timesteps | 37142    |
# | train/             |          |
# |    actor_loss      | -81.9    |
# |    critic_loss     | 3.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37041    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.6     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1128     |
# |    fps             | 99       |
# |    time_elapsed    | 373      |
# |    total_timesteps | 37289    |
# | train/             |          |
# |    actor_loss      | -73.2    |
# |    critic_loss     | 2.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37188    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.6     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1132     |
# |    fps             | 99       |
# |    time_elapsed    | 374      |
# |    total_timesteps | 37434    |
# | train/             |          |
# |    actor_loss      | -84.1    |
# |    critic_loss     | 3.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37333    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.6     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1136     |
# |    fps             | 100      |
# |    time_elapsed    | 375      |
# |    total_timesteps | 37574    |
# | train/             |          |
# |    actor_loss      | -81.7    |
# |    critic_loss     | 3.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37473    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1140     |
# |    fps             | 100      |
# |    time_elapsed    | 376      |
# |    total_timesteps | 37719    |
# | train/             |          |
# |    actor_loss      | -89      |
# |    critic_loss     | 3.85     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37618    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1144     |
# |    fps             | 100      |
# |    time_elapsed    | 378      |
# |    total_timesteps | 37863    |
# | train/             |          |
# |    actor_loss      | -80      |
# |    critic_loss     | 4.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37762    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 1148     |
# |    fps             | 100      |
# |    time_elapsed    | 379      |
# |    total_timesteps | 38009    |
# | train/             |          |
# |    actor_loss      | -79.7    |
# |    critic_loss     | 2.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37908    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.7     |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 1152     |
# |    fps             | 100      |
# |    time_elapsed    | 381      |
# |    total_timesteps | 38152    |
# | train/             |          |
# |    actor_loss      | -81.4    |
# |    critic_loss     | 4.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38051    |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 69
#      67 # Навчання моделей
#      68 print("Навчання TD3...")
# ---> 69 td3_model.learn(total_timesteps=100000, callback=td3_callback)
#      70 print("Навчання DDPG...")
#      71 ddpg_model.learn(total_timesteps=100000, callback=ddpg_callback)
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\stable_baselines3\td3\td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\stable_baselines3\td3\td3.py:189, in TD3.train(self, gradient_steps, batch_size)
#     187 self.critic.optimizer.zero_grad()
#     188 critic_loss.backward()
# --> 189 self.critic.optimizer.step()
#     191 # Delayed policy updates
#     192 if self._n_updates % self.policy_delay == 0:
#     193     # Compute actor loss
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\torch\optim\optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     482         else:
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#     490 # call optimizer step post hooks
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\torch\optim\adam.py:223, in Adam.step(self, closure)
#     211     beta1, beta2 = group["betas"]
#     213     has_complex = self._init_group(
#     214         group,
#     215         params_with_grad,
#    (...)
#     220         state_steps,
#     221     )
# --> 223     adam(
#     224         params_with_grad,
#     225         grads,
#     226         exp_avgs,
#     227         exp_avg_sqs,
#     228         max_exp_avg_sqs,
#     229         state_steps,
#     230         amsgrad=group["amsgrad"],
#     231         has_complex=has_complex,
#     232         beta1=beta1,
#     233         beta2=beta2,
#     234         lr=group["lr"],
#     235         weight_decay=group["weight_decay"],
#     236         eps=group["eps"],
#     237         maximize=group["maximize"],
#     238         foreach=group["foreach"],
#     239         capturable=group["capturable"],
#     240         differentiable=group["differentiable"],
#     241         fused=group["fused"],
#     242         grad_scale=getattr(self, "grad_scale", None),
#     243         found_inf=getattr(self, "found_inf", None),
#     244     )
#     246 return loss
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\torch\optim\optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\torch\optim\adam.py:784, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     781 else:
#     782     func = _single_tensor_adam
# --> 784 func(
#     785     params,
#     786     grads,
#     787     exp_avgs,
#     788     exp_avg_sqs,
#     789     max_exp_avg_sqs,
#     790     state_steps,
#     791     amsgrad=amsgrad,
#     792     has_complex=has_complex,
#     793     beta1=beta1,
#     794     beta2=beta2,
#     795     lr=lr,
#     796     weight_decay=weight_decay,
#     797     eps=eps,
#     798     maximize=maximize,
#     799     capturable=capturable,
#     800     differentiable=differentiable,
#     801     grad_scale=grad_scale,
#     802     found_inf=found_inf,
#     803 )
#
# File c:\Users\g00n3\anaconda3\Lib\site-packages\torch\optim\adam.py:543, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     540 torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - beta1)
#     542 torch._foreach_mul_(device_exp_avg_sqs, beta2)
# --> 543 torch._foreach_addcmul_(
#     544     device_exp_avg_sqs, device_grads, device_grads, 1 - beta2
#     545 )
#     547 # Delete the local intermediate since it won't be used anymore to save on peak memory
#     548 del device_grads
#
# KeyboardInterrupt:
